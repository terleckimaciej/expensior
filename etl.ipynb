# %%
import pandas as pd

# %%
file_name = "Zestawienie operacji za 01.01.2010 - 28.11.2025.csv"

# %%
df = pd.read_csv(file_name, encoding="latin2")

df.head()
# Out:
#   Data operacji Data waluty    Typ transakcji    Kwota Waluta  \
# 0    2025-11-28  2025-11-26    Płatnoć kartš   -31.00    PLN
# 1    2025-11-28  2025-11-26    Płatnoć kartš   -72.16    PLN
# 2    2025-11-28  2025-11-26    Płatnoć kartš   -50.22    PLN
# 3    2025-11-27  2025-11-27  Przelew na konto  6281.91    PLN
# 4    2025-11-25  2025-11-23    Płatnoć kartš    -4.30    PLN
#
#                              Opis transakcji  \
# 0  Tytuł: 010061097 74169505330633307706340
# 1  Tytuł: 010059127 74043215330148157931508
# 2           Tytuł:  74988855330496415991685
# 3                         Rachunek nadawcy :
# 4  Tytuł: 000498849 74230785327180203293377
#
#                                           Unnamed: 6  \
# 0  Lokalizacja: Adres: OLLI S C Miasto: WARSZAWA ...
# 1  Lokalizacja: Adres: Apteka przy Domaniewskiej ...
# 2  Lokalizacja: Adres: JMP S.A. BIEDRONKA 7224 Mi...
# 3                   06 1240 0030 1111 1111 1111 5990
# ...
