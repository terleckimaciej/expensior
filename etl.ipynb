# %%
import pandas as pd

# %%
#tylko w colab
from google.colab import drive
drive.mount('/content/drive')

import os
os.listdir('/content/drive/MyDrive')

df = pd.read_csv('/content/drive/MyDrive/Zestawienie operacji za 01.01.2010 - 28.11.2025.csv', encoding="latin2")

df.head()
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# ['Dokument bez nazwy.gdoc',
#  'Test prezentacja ang.gdoc',
#  'Maciej Terlecki - konspekt.odt',
#  'Spadek wartości zboza z rzeczpospolitej jako przyczyna zahamowania wzrostu gospodarczego panstwa w XVII wieku.pdf',
#  'Classroom',
#  'Mikroekonomia II_praca domowa 1z7.gslides',
#  'cps09mar.xlsx',
#  'EX_5.ipynb',
#  'podanie prodziekan.pdf',
#  'firms.csv',
#  '[RP_08_15.12].mp4',
#  '[RP_09_29.12].mp4',
#  '[RP_10_05.01] (1).mp4',
#  '[RP_10_05.01].mp4',
#  'RP_aktywnosc9 (1).xlsx',
#  'RP_aktywnosc9.xlsx',
#  'Referat Terlecki.gdoc',
#  'Referat Terlecki.docx',
#  'egz1_2018_odp.pdf',
#  'egz1_2018_odp.gdoc',
#  'Colab Notebooks',
#  'prez skrypt.gdoc',
#  'prez przxestepczosc.gslides',
#  'kodzik.do',
#  'Handel Miedzynarodowy-Projekt-Faza 1.gdoc',
#  'kolokwium hm 2022.docx',
#  '6_OPCJE_Model_Blacka_Scholesa.xlsx',
#  '4_5_6_7_OPCJE_Zad_ROZ.xlsx',
#  'listings.csv',
#  'WP5_numpy (1).ipynb',
#  'bieda_konspekt_v1.docx',
#  'WP6_pandas.ipynb',
#  'EX_3 (1).ipynb',
#  'WP8_Pandas_practice-4.ipynb',
#  'Praca domowa dla chętnych 2.ipynb',
#  'krisztof',
#  'WP6_Pandas2 (1).ipynb',
#  'v-dem',
#  'Wstep do DE',
#  'IT Salary Survey EU (Responses) - Dec_2023.csv',
#  'cexdata.dta',
#  'pd1.ipynb',
#  'cps09mar.csv.csv',
#  'pd_2.ipynb',
#  'Wymiana_pasazerska_wraz_z_rankingiem_na_strone_2022.xlsx',
#  'prezka szwecja skrypt.gdoc',
#  'notatki 14-10-2024.xlsx',
#  'wiselka (i srolonia)',
#  'snippety',
#  'gorka itp',
#  'terlecki.pdf',
#  'Życiorys zwierzęcia.gdoc',
#  'Życiorys – mięta.gdoc',
#  'list_mot_terlecki.gdoc',
#  'list_mot _terlecki_og.gdoc',
#  'Dokument bez tytułu (4).gdoc',
#  'zdj cv',
#  'The Bolsonaro Phenomenon.pdf',
#  'Determinanty backlidingu W Brazylii.pdf',
#  'Kopia lic 29.04.gdoc',
#  'art praca',
#  'FULLTEXT01.pdf',
#  'Dokument bez tytułu (3).gdoc',
#  'Dokument bez tytułu (2).gdoc',
#  'Kopia lic - przypisy, komentarze.gdoc',
#  'Zalacznik_D_do_Uchwaly_-_Wymagany_uklad_pracy.pdf',
#  'Zalacznik_D_do_Uchwaly_-_Wymagany_uklad_pracy.doc',
#  'Dokument bez tytułu (1).gdoc',
#  'Dokument bez tytułu.gdoc',
#  'stargazer.odt',
#  'stargazer.gdoc',
#  'lic.gdoc',
#  'Wzor_oswiadczenia_SI_pl.docx',
#  'Kopia_lic_dostosowana (1).docx',
#  'Kopia_lic_z_pelna_struktura.docx',
#  'edp raport terleckimaciej.gdoc',
#  'pracka ekonometria.gdoc',
#  'maciej terlecki.doc',
#  'NVIDIA_raport_osoba3_FULL.docx',
#  'NVIDIA_raport_FULL_FINAL.docx',
#  'NVIDIA_raport_ANALIZA_FULL.docx',
#  'wyklady zarzadzanie',
#  'terlecki prez EDP.pptx',
#  'maciej terlecki.pdf',
#  '15.06-22.06',
#  'maciej terlecki.docx',
#  'praktyki',
#  'CV - Maciej Terlecki..gdoc',
#  'Data Engineering with Google Cloud Platform_ A guide to -- ADI_ WIJAYA -- 2, 2024 -- Packt Publishing, Limited -- 9781835080115 -- e80c75f04a415e8a2c7205943dc0852d -- Anna’s Archive.pdf',
#  'Yuval Noah Harari - Nexus. Krótka historia informacji (2024) [audiobook PL].rar',
#  'Nexus',
#  'Zestawienie operacji za 27.05.2025 - 25.08.2025.xls',
#  'przyg_rozm_o_prace.docx',
#  'Zalacznik_8_-_Formularz_oceny (1).docx',
#  'Untitled document.gdoc',
#  'Checklista_Preboarding_Pracownik_12.08.xlsx',
#  '05.ipynb',
#  '05',
#  'Wyciag_9_91102011690000810203195708_20250929652246359.pdf',
#  'Untitled spreadsheet (1).gsheet',
#  'Zestawienie operacji za 26.08.2025 - 24.11.2025.csv',
#  'Zestawienie operacji za 01.01.2010 - 28.11.2025.csv',
#  'Zestawienie operacji za 30.08.2025 - 28.11.2025.xls',
#  'Untitled spreadsheet.gsheet',
#  'Zestawienie operacji za 01.01.2010 - 28.11.2025.gsheet']

# %%
file_name = "Zestawienie operacji za 01.01.2010 - 28.11.2025.csv"

# %%
df = pd.read_csv(file_name, encoding="latin2")

df.head()
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# /tmp/ipython-input-1945557838.py in <cell line: 0>()
# ----> 1 df = pd.read_csv(file_name, encoding="latin2")
#       2
#       3 df.head()
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
#    1025
# -> 1026     return _read(filepath_or_buffer, kwds)
#    1027
#    1028
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _read(filepath_or_buffer, kwds)
#     618
#     619     # Create the parser.
# --> 620     parser = TextFileReader(filepath_or_buffer, **kwds)
#     621
#     622     if chunksize or iterator:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in __init__(self, f, engine, **kwds)
#    1618
#    1619         self.handles: IOHandles | None = None
# -> 1620         self._engine = self._make_engine(f, self.engine)
#    1621
#    1622     def close(self) -> None:
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/parsers/readers.py in _make_engine(self, f, engine)
#    1878                 if "b" not in mode:
#    1879                     mode += "b"
# -> 1880             self.handles = get_handle(
#    1881                 f,
#    1882                 mode,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     726
#     727     # open URLs
# --> 728     ioargs = _get_filepath_or_buffer(
#     729         path_or_buf,
#     730         encoding=encoding,
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in _get_filepath_or_buffer(filepath_or_buffer, encoding, compression, mode, storage_options)
#     382         # assuming storage_options is to be interpreted as headers
#     383         req_info = urllib.request.Request(filepath_or_buffer, headers=storage_options)
# --> 384         with urlopen(req_info) as req:
#     385             content_encoding = req.headers.get("Content-Encoding", None)
#     386             if content_encoding == "gzip":
#
# /usr/local/lib/python3.12/dist-packages/pandas/io/common.py in urlopen(*args, **kwargs)
#     287     import urllib.request
#     288
# --> 289     return urllib.request.urlopen(*args, **kwargs)
#     290
#     291
#
# /usr/lib/python3.12/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     213     else:
#     214         opener = _opener
# --> 215     return opener.open(url, data, timeout)
#     216
#     217 def install_opener(opener):
#
# /usr/lib/python3.12/urllib/request.py in open(self, fullurl, data, timeout)
#     519         for processor in self.process_response.get(protocol, []):
#     520             meth = getattr(processor, meth_name)
# --> 521             response = meth(req, response)
#     522
#     523         return response
#
# /usr/lib/python3.12/urllib/request.py in http_response(self, request, response)
#     628         # request was successfully received, understood, and accepted.
#     629         if not (200 <= code < 300):
# --> 630             response = self.parent.error(
#     631                 'http', request, response, code, msg, hdrs)
#     632
#
# /usr/lib/python3.12/urllib/request.py in error(self, proto, *args)
#     557         if http_err:
#     558             args = (dict, 'default', 'http_error_default') + orig_args
# --> 559             return self._call_chain(*args)
#     560
#     561 # XXX probably also want an abstract factory that knows when it makes
#
# /usr/lib/python3.12/urllib/request.py in _call_chain(self, chain, kind, meth_name, *args)
#     490         for handler in handlers:
#     491             func = getattr(handler, meth_name)
# --> 492             result = func(*args)
#     493             if result is not None:
#     494                 return result
#
# /usr/lib/python3.12/urllib/request.py in http_error_default(self, req, fp, code, msg, hdrs)
#     637 class HTTPDefaultErrorHandler(BaseHandler):
#     638     def http_error_default(self, req, fp, code, msg, hdrs):
# --> 639         raise HTTPError(req.full_url, code, msg, hdrs, fp)
#     640
#     641 class HTTPRedirectHandler(BaseHandler):
#
# HTTPError: HTTP Error 404: Not Found

# %%
countries = (
    df['Unnamed: 6']
    .str.extract(r"Kraj:\s*(.*)", expand=False)
    .str.strip()
)

countries_df=countries.value_counts()

# %%
countries_df
# Out:
# Unnamed: 6
# POLSKA                       2807
# IRLANDIA                       24
# STANY ZJEDNOCZONE AMERYKI      16
# POLSKA"                         9
# HOLANDIA                        8
# GRUZJA                          8
# CZARNOGÓRA                      5
# LUKSEMBURG                      4
# NIEMCY                          3
# SŁOWACJA                        3
# NOWA ZELANDIA                   2
# WIELKA BRYTANIA                 2
# HONG-KONG                       1
# HISZPANIA                       1
# LITWA                           1
# FRANCJA                         1
# Name: count, dtype: int64

# %%
from google.colab import files
import pandas as pd

countries_df.to_excel("countries_df.xlsx", index=True)
files.download("countries_df.xlsx")

# %%
#creating schema of output, cleaned df

df_std = pd.DataFrame(index=df.index)

df_std["transaction_id"] = None
df_std["date"] = df["Data waluty"]
df_std["transaction_type"] = df["Typ transakcji"]
df_std["amount"] = (
    df["Kwota"]
    .astype(str)
    .str.replace(" ", "", regex=False)
    .str.replace(",", ".", regex=False)
    .astype(float)
)
df_std["currency"] = df["Waluta"]
df_std["description"] = None
df_std["merchant"] = None
df_std["country"] = None
df_std["city"] = None
df_std["category"] = None
df_std["subcategory"] = None
df_std["rule_id"] = None

# %%
df_std
# Out:
#      transaction_id        date                    transaction_type   amount  \
# 0              None  2025-11-26                      Płatnoć kartš   -31.00
# 1              None  2025-11-26                      Płatnoć kartš   -72.16
# 2              None  2025-11-26                      Płatnoć kartš   -50.22
# 3              None  2025-11-27                    Przelew na konto  6281.91
# 4              None  2025-11-23                      Płatnoć kartš    -4.30
# ...             ...         ...                                 ...      ...
# 5243           None  2020-11-13                      Płatnoć kartš   -11.80
# 5244           None  2020-11-13  Przelew na telefon przychodz. zew.    50.00
# 5245           None  2020-11-05                      Płatnoć kartš    -8.60
# 5246           None  2020-11-05                    Przelew na konto   400.00
# 5247           None  2020-10-28                    Przelew na konto    55.67
#
#      currency description merchant country  city category subcategory rule_id
# 0         PLN        None     None    None  None     None        None    None
# 1         PLN        None     None    None  None     None        None    None
# 2         PLN        None     None    None  None     None        None    None
# 3         PLN        None     None    None  None     None        None    None
# 4         PLN        None     None    None  None     None        None    None
# ...       ...         ...      ...     ...   ...      ...         ...     ...
# 5243      PLN        None     None    None  None     None        None    None
# 5244      PLN        None     None    None  None     None        None    None
# 5245      PLN        None     None    None  None     None        None    None
# 5246      PLN        None     None    None  None     None        None    None
# 5247      PLN        None     None    None  None     None        None    None
#
# [5248 rows x 12 columns]

# %%
#dictionary to map transaction type names - translate and standarize
transaction_type_map = {
    "Płatność kartą": "card_payment",
    "Płatnoć kartš": "card_payment",

    "Autooszczędzanie": "auto_savings",

    "Płatność web - kod mobilny": "",
    "Płatnoć web - kod mobilny": "web_payment_blik",

    "Przelew na telefon przychodz. zew.": "transfer_blik",
    "Przelew na telefon przychodz. wew.": "transfer_blik",

    "Przelew na konto": "transfer_to_account",
    "Przelew z rachunku": "transfer_from_account",

    "Zakup w terminalu - kod mobilny": "terminal_payment_blik",

    "Opłata za użytkowanie karty": "card_fee",

    "Zwrot w terminalu": "refund",
    "Zwrot płatności kartą": "refund",
    "Zwrot płatnoci kartš": "refund",

    "Zlecenie stałe": "standing_order",

    "Wypłata z bankomatu": "atm_withdrawal",
    "Wypłata w bankomacie - kod mobilny": "atm_withdrawal",
    "Wypłata w bankomacie - czek": "atm_withdrawal",

    "Obciążenie": "pko_charge",
    "Obcišżenie": "pko_charge",

    "Uznanie": "pko_credit",

    "Naliczenie odsetek": "interest_accrued"
}

# %%
#function to map
def normalize_transaction_type(value, mapping):
    if pd.isna(value):
        return "unknown"
    cleaned = str(value).strip()
    if cleaned in mapping:
        return mapping[cleaned]

    # jeśli nie ma w mapie → można zwrócić cleaned lub "unknown"
    return cleaned

# %%
df_std["transaction_type"] = df["Typ transakcji"].apply(
    lambda x: normalize_transaction_type(x, transaction_type_map)
)

# %% [markdown]
# processing of first transaction type (card payment)

# %%
#mask on transaction type (we have same index for df and df_std)
mask = df_std["transaction_type"] == "card_payment"

# extraction of transaction id
df_std.loc[mask, "transaction_id"] = (
    df.loc[mask, "Opis transakcji"]
      .fillna("")
      .str.extract(r"Tytuł:\s*([\d\s]+)", expand=False)
      .fillna("")
      .str.replace(" ", "", regex=False)
      .str.strip()
)

mask = df_std["transaction_type"] == "card_payment"

# extraction of the raw DESCRIPTION
df_std.loc[mask, "description"] = (
    df.loc[mask, "Unnamed: 6"]
      .str.extract(r"Adres:\s*(.*?)\s*Miasto:", expand=False)
      .str.strip()
      .str.upper()
)

# extracion of the CITY"
df_std.loc[mask, "city"] = (
    df.loc[mask, "Unnamed: 6"]
      .str.extract(r"Miasto:\s*([A-Za-zĄĆĘŁŃÓŚŹŻąćęłńóśźż0-9\s]+?)\s*Kraj:", expand=False)
      .str.strip()
      .str.upper()
)

# extraction of the COUNTRY
df_std.loc[mask, "country"] = (
    df.loc[mask, "Unnamed: 6"]
      .str.extract(r"Kraj:\s*(.*)", expand=False)
      .str.strip()
      .str.upper()
)

#manually mapping cities and countries mismached that appear multiple times
#eg. vending machines mayment - has some small city where the vending machine owner is from, not where the transaction happened
#or google play transactions - has dublin, ireland where google avoids paying taxes, but the transaction was made on my phone not in dublin

# %% [markdown]
# processing the second transaction type

# %%
df_std
# Out:
#                         transaction_id        date     transaction_type  \
# 0     01006109774169505330633307706340  2025-11-26         card_payment
# 1     01005912774043215330148157931508  2025-11-26         card_payment
# 2              74988855330496415991685  2025-11-26         card_payment
# 3                                 None  2025-11-27  transfer_to_account
# 4     00049884974230785327180203293377  2025-11-23         card_payment
# ...                                ...         ...                  ...
# 5243           74378830318043513007084  2020-11-13         card_payment
# 5244                              None  2020-11-13        transfer_blik
# 5245           74378830310043185547183  2020-11-05         card_payment
# 5246                              None  2020-11-05  transfer_to_account
# 5247                              None  2020-10-28  transfer_to_account
#
#        amount currency                description merchant country       city  \
# 0      -31.00      PLN                   OLLI S C     None  POLSKA   WARSZAWA
# 1      -72.16      PLN  APTEKA PRZY DOMANIEWSKIEJ     None  POLSKA   WARSZAWA
# 2      -50.22      PLN    JMP S.A. BIEDRONKA 7224     None  POLSKA   WARSZAWA
# 3     6281.91      PLN                       None     None    None       None
# 4       -4.30      PLN            ZABKA Z5795 K.1     None  POLSKA    SIEDLCE
# ...       ...      ...                        ...      ...     ...        ...
# 5243   -11.80      PLN           CYGARO EWA KAFAR     None  POLSKA  NOWA WOLA
# 5244    50.00      PLN                       None     None    None       None
# 5245    -8.60      PLN           CYGARO EWA KAFAR     None  POLSKA  NOWA WOLA
# 5246   400.00      PLN                       None     None    None       None
# 5247    55.67      PLN                       None     None    None       None
#
#      category subcategory rule_id
# 0        None        None    None
# 1        None        None    None
# 2        None        None    None
# 3        None        None    None
# 4        None        None    None
# ...       ...         ...     ...
# 5243     None        None    None
# 5244     None        None    None
# 5245     None        None    None
# 5246     None        None    None
# 5247     None        None    None
#
# [5248 rows x 12 columns]
