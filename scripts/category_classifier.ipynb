# %%
import pandas as pd

# %%
file_name = "../data/statements cleaned/transactions_cleaned.csv"
df = pd.read_csv(file_name, encoding="latin2")

# %%
import os


# Przykładowe reguły startowe 
rules_df = pd.DataFrame([
    {
        "id": 1,
        "pattern": r"BIEDRONKA",
        "match_type": "contains",
        "source_column": "description",
        "merchant": "BIEDRONKA",
        "category": "groceries",
        "subcategory": "biedronka",
        "priority": 10
    },
    {
        "id": 2,
        "pattern": r"ŻABKA",
        "match_type": "contains",
        "source_column": "description",
        "merchant": "ZABKA",
        "category": "groceries",
        "subcategory": "zabka",
        "priority": 10
    },
    {
        "id": 3,
        "pattern": r"APTEKA",
        "match_type": "contains",
        "source_column": "description",
        "merchant": "APTEKA",
        "category": "health",
        "subcategory": "pharmacy",
        "priority": 10
    }
])

# 3. Zapis do CSV w lokalizacji repo
output_path = "../data/rules.csv"
rules_df.to_csv(output_path, index=False, encoding="utf-8")

output_path
# Out:
# '../data/rules.csv'
